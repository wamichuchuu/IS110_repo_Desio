# %% [markdown]
# **CHAPTER 2**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
name = input("Enter your name: ")

print("Hello", name)
# Out:
# Enter your name: Chuck
# Hello Chuck

# %%
name = input("Enter your name: ")

print("Hello", name)
# Out:
# Enter your name: Juami Shaniqua
# Hello Juami Shaniqua

# %%
hours = float(input("Enter Hours: "))
rate = float(input("Enter Rate: "))

pay = hours * rate

print("Pay: ", pay)
# Out:
# Enter Hours: 35
# Enter Rate: 2.75
# Pay:  96.25

# %%
width = 17
height = 12.0

print("width//2 =", width//2, type(width//2))
print("width/2.0 =", width/2.0, type(width/2.0))
print("height/3 =", height/3, type(height/3))
print("1 + 2 * 5 =", 1 + 2 * 5, type(1 + 2 * 5))
# Out:
# width//2 = 8 <class 'int'>
# width/2.0 = 8.5 <class 'float'>
# height/3 = 4.0 <class 'float'>
# 1 + 2 * 5 = 11 <class 'int'>

# %%
number = input("Enter a number:")
num_val = float(number)
square = num_val ** 2
print(f"The square of {number} is {square}")
# Out:
# Enter a number:3
# The square of 3 is 9.0

# %%
celsius = input("Enter Celsius temperature: ")
fahrenheit = (float(celsius) * 9/5) + 32
print(f"The temperature is {fahrenheit} degrees Fahrenheit")
# Out:
# Enter Celsius temperature: 36
# The temperature is 96.8 degrees Fahrenheit
