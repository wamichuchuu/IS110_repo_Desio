# %% [markdown]
# **CHAPTER 5**

# %% [markdown]
# **Exercise 1**

# %% [markdown]
# Investigate on the difference between `is` and `==` given the following variables.
# ```python
# a = 2
# b = 2.0
# c = a
# ```

# %%
a = 2
b = 2.0
c = a

print(f"a == b: {a == b}")
print(f"a is b: {a is b}")

print(f"a == c: {a == c}")
print(f"a is c: {a is c}")

print(f"Memory ID of a: {id(a)}")
print(f"Memory ID of b: {id(b)}")
print(f"Memory ID of c: {id(c)}")
# Out:
# a == b: True
# a is b: False
# a == c: True
# a is c: True
# Memory ID of a: 11645384
# Memory ID of b: 139420307614608
# Memory ID of c: 11645384

# %% [markdown]
# **CHALLENGE**

# %% [markdown]
# **Challenge 1**

# %% [markdown]
# Write a program which repeatedly reads numbers until the user enters "done". Once "done" is entered, print out the total, count, and average of the numbers. If the user enters anything other than a number, detect their mistake using try and except and print an error message and skip to the next number.
#
#     Enter a number: 4
#     Enter a number: 5
#     Enter a number: bad data
#     Invalid input
#     Enter a number: 7
#     Enter a number: done
#     16 3 5.333333333333333
#
# [PEW] E5.1

# %%
total = 0
count = 0

while True:
    user_input = input("Enter a number: ")

    if user_input.lower() == 'done':
        break

    try:
        number = float(user_input)
        total += number
        count += 1
    except ValueError:
        print("Invalid input")
        continue

if count > 0:
    average = total / count
    print(total, count, average)
else:
    print("No numbers were entered.")
# Out:
# Enter a number: 6
# Enter a number: 7
# Enter a number: 5
# Enter a number: 7
# Enter a number: 9
# Enter a number: stop
# Invalid input
# Enter a number: done
# 34.0 5 6.8

# %% [markdown]
# **Challenge 2**

# %% [markdown]
# Write another program that prompts for a list of numbers as above and at the end prints out both the maximum and minimum of the numbers instead of the average.
#
# [PEW] E5.2

# %%
maximum = None
minimum = None

while True:
    user_input = input("Enter a number: ")

    if user_input.lower() == 'done':
        break

    try:
        number = float(user_input)

        if maximum is None or number > maximum:
            maximum = number
        if minimum is None or number < minimum:
            minimum = number

    except ValueError:
        print("Invalid input")
        continue

print("Maximum:", maximum)
print("Minimum:", minimum)
# Out:
# Enter a number: 100
# Enter a number: 10 000
# Invalid input
# Enter a number: 1
# Enter a number: 5
# Enter a number: 80
# Enter a number: 67
# Enter a number: 5
# Enter a number: done
# Maximum: 100.0
# Minimum: 1.0
